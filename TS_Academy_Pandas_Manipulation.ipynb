# %% [markdown]
# <a href="https://colab.research.google.com/github/Michaelfawoye/Review-Of-2019-Data-Analyst-Job-Application/blob/main/TS_Academy_Pandas_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Python Modules and Libraries**
# **1.1 What is a Module?**
#
# A module is simply a Python file that contains code such as functions or variables that can be reused in other Python programs.
#
# **You can think of a module as a toolbox:**
#
# instead of rebuilding every tool from scratch, you can import and use tools that already exist.

# %% [markdown]
# **Example:** Creating a Module
#
# Create a file called **calculator.py**:

# %%
# %%writefile calculator.py

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b
# Out:
# Writing calculator.py

# %%
# main.py
import calculator

result = calculator.add(5, 3)
print(result)  # Output: 8

# %% [markdown]
# **1.2 What is a Library?**
#
# A library (also called a package) is a collection of related modules that are grouped together to provide a set of tools for a specific purpose.
#
# **A library contains many modules (small toolboxes) that help you do specific tasks.**
#
# **Python has thousands of libraries, but some of the most commonly used ones are:**
#
# * **NumPy** → Used for numerical computing and fast mathematical operations.
#
# * **Pandas** → Used for working with datasets, data tables, and data cleaning.
# * **Matplotlib** → Used for creating plots, charts, and visualizations.
# * **Scikit-Learn (sklearn)** → Used for machine learning algorithms and model building.

# %% [markdown]
# **Example:**
#
# If you want to calculate the square root of a number, instead of writing your own function, you can use the math library

# %%
# instead of writing a full function like this
def square_root(number):
    return number ** 0.5

print(square_root(25))
# Out:
# 5.0

# %%
# you can just import a math library
import math


print(math.sqrt(25))
# Out:
# 5.0

# %% [markdown]
# **Python has thousands of libraries, but some of the most commonly used ones are:**
#
# * **NumPy** → Used for numerical computing and fast mathematical operations.
#
# * **Pandas** → Used for working with datasets, data tables, and data cleaning.
# * **Matplotlib** → Used for creating plots, charts, and visualizations.
# * **Scikit-Learn (sklearn)** → Used for machine learning algorithms and model building.

# %% [markdown]
# **Difference Between Modules and Libraries**
#
# | Feature           | **Module**                                                            | **Library**                                         |
# | ----------------- | --------------------------------------------------------------------- | --------------------------------------------------- |
# | **Definition**    | A single Python file containing code (functions, classes, variables). | A collection of multiple modules packaged together. |
# | **Size**          | Small                                                                 | Larger                                              |
# | **Purpose**       | Provides specific, small tools                                        | Provides many tools for bigger tasks                |
# | **Example Files** | `calculator.py`, `math.py`                                            | pandas, numpy, matplotlib                           |
# | **Analogy**       | One small toolbox                                                     | A big toolbox filled with many smaller toolboxes    |

# %% [markdown]
# **1.3 Ways to Import Modules/libraries**
#
# Python gives different ways to bring a module into your program.
#
# 1. **Import the whole module**

# %%
import math

print(math.sqrt(16))
# Out:
# 4.0

# %% [markdown]
# 2. **Import specific things from a module**
#
# You only bring in what you need.

# %%
from math import sqrt

print(sqrt(16))
# Out:
# 4.0

# %% [markdown]
# 3. **Import a module with a shorter name (alias)**
#
# Sometimes module names are long, so Python lets you give them a short nickname (alias).
# This makes your code shorter, cleaner, and easier to type.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * pd → short name for pandas
#
# * np → short name for numpy
#
# * plt → short name for matplotlib.pyplot

# %% [markdown]
# ## **1.4 Installing External Libraries**
#
# Not all libraries come built-in with Python.
# Some need to be installed before you can use them.
#
# **How to Install a Library Using pip**
#
# pip is Python’s package installer — it helps you download and install libraries from the internet.

# %% [markdown]
# **Example:**
# * pip install numpy
# * pip install matplotlib

# %% [markdown]
# **Checking What’s Installed**
#
# You can see all the Python libraries currently installed on your system.

# %% [markdown]
# 1. **Using pip list**
#
# This command shows every installed package and its version.

# %%
# !pip list

# %% [markdown]
# 2. **Using pip show**
#
# This shows details about one specific library.

# %%
# !pip show numpy

# %% [markdown]
# # **2. Introduction to Pandas**
#
# **2.1 What is Pandas?**
#
# Pandas is a Python library used for working with data, especially data that looks like a table (rows and columns).
#
# **You can think of it like using Excel inside Python, but with much more power.**
#
# * Pandas makes it easy to **clean**, **analyze**, and **manipulate data**.
#
# ###**How Pandas Works**
#
# Pandas is built on top of NumPy and provides two main data structures:
#
# * Series → one column of data (1-dimensional)
#
# * DataFrame → a full table of data (2-dimensional)
#
# A DataFrame is similar to:
#
# * a spreadsheet
#
# * a database table
#
# * or an Excel sheet

# %% [markdown]
# **2.2 What Problems Does Pandas Solve?**
#
# 1. **Working with Large Datasets**
#
#
# Imagine you have a spreadsheet with 558,837 rows of car sales data.
# A file this big would make Excel slow or even crash…
#
# **…but Pandas can load, handle, and process it quickly and smoothly.**
#
# Pandas is designed to work with large datasets that traditional tools struggle with, making it perfect for real-world data analysis.

# %% [markdown]
# **2.3 Loading a Dataset with Pandas**

# %%
import pandas as pd #first import pandas library

df = pd.read_csv("/content/drive/MyDrive/Datasets/car_prices.csv")

 #only works on your local machine(on your laptop)
 #df = pd.read_csv('C:/Users/YourName/Desktop/data.csv')

# %% [markdown]
# **Understanding the Code**
#
# pd.read_csv() → This function loads data from a CSV file.
# Pandas automatically figures out:
#
# * the columns
#
# * the rows
#
# * the data types
#
# The loaded data is stored in a DataFrame called df.
#
# df is a standard, widely used name for a DataFrame among data scientists.

# %% [markdown]
# **2.4 File Path Reminder**
#
# When you use pd.read_csv("file_path"), Python looks for the file at the location you specify.
#
# * If the file is not there, Python will show an error:
# $$FileNotFoundError$$
#
# * On Google Colab, the file path might be something like:

# %%
"/content/drive/MyDrive/car_prices.csv"

# %% [markdown]
# * On your local computer, it might look like:

# %%
"C:/Users/YourName/Documents/car_prices.csv"

# %% [markdown]
# **2.5 Other File Formats with Pandas**
#
# |File Format|Pandas Function|Example Code|Notes|
# |-----------|---------------|------------|-----|
# |Excel (.xls/.xlsx)|pd.read_excel()|pd.read_excel('file.xlsx')|Requires openpyxl or xlrd package
# |JSON|pd.read_json()|pd.read_json('file.json')|Useful for nested data structures (e.g., from APIs)
# |SQL Databases|pd.read_sql() / pd.read_sql_query()|pd.read_sql_query('SELECT * FROM table', connection)|Works with databases like SQLite, PostgreSQL, MySQL,

# %% [markdown]
# **Quick Check: Did It Load Successfully?**
#
# After loading, always verify your data:

# %%
# View the first 5 rows
df.head()


# df.head() shows the first 5 rows. This gives you a quick glimpse of the data structure
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
# Preview the last few rows of the dataset
df.tail()
# Out:
#         year    make   model         trim       body transmission  \
# 558832  2015     Kia    K900       Luxury      Sedan          NaN
# 558833  2012     Ram    2500  Power Wagon   Crew Cab    automatic
# 558834  2012     BMW      X5    xDrive35d        SUV    automatic
# 558835  2015  Nissan  Altima        2.5 S      sedan    automatic
# 558836  2014    Ford   F-150          XLT  SuperCrew    automatic
#
#                       vin state  condition  odometer   color interior  \
# 558832  knalw4d4xf6019304    in       45.0   18255.0  silver    black
# 558833  3c6td5et6cg112407    wa        5.0   54393.0   white    black
# 558834  5uxzw0c58cl668465    ca       48.0   50561.0   black    black
# 558835  1n4al3ap0fc216050    ga       38.0   16658.0   white    black
# 558836  1ftfw1et2eke87277    ca       34.0   15008.0    gray     gray
#
#                                                    seller      mmr  \
# 558832                                   avis corporation  35300.0
# ...

# %% [markdown]
# **Why is this useful?**
#
# * Get a feel for what the data looks like
# * Spot obvious errors or patterns
# * See the range of values (first vs last entries)
# * Verify data loaded correctly

# %% [markdown]
# # **3. Understanding Your Data Quickly**
#
#
#
# **3.1 Random Sampling**
#
# Sometimes you want to see random rows, not just the first or last.

# %%
# View 5 random rows
df.sample(5)
# Out:
#         year       make              model       trim   body transmission  \
# 267488  2012     Nissan             Altima      2.5 S  Sedan    automatic
# 442807  2013     Nissan             Altima        2.5  sedan    automatic
# 182709  2014  Chevrolet  Corvette Stingray       Base  Coupe    automatic
# 36548   2012        GMC             Acadia     Denali    SUV    automatic
# 243569  2010      Dodge            Charger  SXT Fleet  Sedan    automatic
#
#                       vin state  condition  odometer  color interior  \
# 267488  1n4al2ap9cn434269    fl       35.0   30457.0  white    black
# 442807  1n4al3ap2dc221103    tn       32.0   20270.0  black    black
# 182709  1g1yb2d73e5101276    fl        4.0    6847.0    red      red
# 36548   1gkkvted4cj222972    nj       37.0  106712.0  white    black
# 243569  2b3ca3cv1ah308540    ga       27.0   76724.0  black    black
#
#                           seller      mmr  sellingprice  \
# ...

# %% [markdown]
# **Why use sampling?**
#
# * Get unbiased view of data (not just first/last)
# * Spot patterns across the entire dataset
# * Useful for large datasets where head/tail might be misleading

# %% [markdown]
# **3.2 The df.info() function gives you a quick summary of your DataFrame.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %% [markdown]
# **What It Does:**
# * Number of rows and columns – how big your dataset is
#
# * Column names – all the features in your data
#
# * Data types - (whether columns are numbers, text, dates, etc.)
#
# * Shows non-null counts  how many values are present (not missing) in each column
#
# * Memory usage – how much memory your dataset uses
#
#
# **3.3 Common Data Types in Pandas**
#
# int64 → Integer Numbers
# * Represents whole numbers (no decimal places)
# * The "64" means it uses 64 bits of memory per value
#
# float64 → Decimal Numbers
# * Represents numbers with decimal points
#
# object → Text / Mixed Data
#
# * Typically used for strings (text data), but can also hold mixed types

# %% [markdown]
# **3.4 Getting Dataset Dimensions**

# %%
# Get shape (rows, columns)
df.shape
# Out:
# (558837, 16)

# %%
# Get number of rows
len(df)
# Out:
# 558837

# %%
# Get number of columns
len(df.columns)
# Out:
# 16

# %% [markdown]
# **3.5 Viewing Column Names**
#
# Get all column names

# %%
df.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['year',
#  'make',
#  'model',
#  'trim',
#  'body',
#  'transmission',
#  'vin',
#  'state',
#  'condition',
#  'odometer',
#  'color',
#  'interior',
#  'seller',
#  'mmr',
#  'sellingprice',
#  'saledate']

# %% [markdown]
# # **4. Checking Unique Values**
# Understanding how many distinct values each column contains helps you know whether a feature is categorical, continuous, or possibly needs cleaning.

# %%
# Number of unique values in each column

print(df.nunique())
# Out:
# year                34
# make                96
# model              973
# trim              1963
# body                87
# transmission         4
# vin             550297
# state               64
# condition           41
# odometer        172278
# color               46
# interior            17
# seller           14263
# mmr               1101
# sellingprice      1887
# saledate          3766
# dtype: int64

# %%
df["make"].nunique()
# Out:
# 96

# %% [markdown]
# **Explanation:**
#
# This displays the number of unique entries in every column of the DataFrame. It’s useful for spotting columns with too many repeated values, IDs, or unexpected categories.

# %% [markdown]
# # **5. Viewing Specific Column Values**
# Sometimes you want to see which values appear most often in a particular column. This helps you understand the distribution of categories.

# %%
print(df['make'].value_counts().head(10))
# Out:
# make
# Ford         93554
# Chevrolet    60197
# Nissan       53946
# Toyota       39871
# Dodge        30710
# Honda        27206
# Hyundai      21816
# BMW          20719
# Kia          18077
# Chrysler     17276
# Name: count, dtype: int64

# %%
print(df['transmission'].value_counts())
# Out:
# transmission
# automatic    475915
# manual        17544
# sedan            15
# Sedan            11
# Name: count, dtype: int64

# %% [markdown]
# **Explanation:**
#
# This shows the top 10 most common car manufacturers in the dataset, ordered from most frequent to least frequent.

# %% [markdown]
# # **6. Summary Statistics**
# **df.describe()** is a quick statistical summary tool that gives you important metrics for only the numeric columns in your dataset (unless you specify otherwise).

# %%
df.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %% [markdown]
# On a DataFrame, Pandas returns the descriptive statistics for each numeric column. Here's what each of those values really means and why they matter in data analysis:
#
# **Count:** Total number of non-null (non-missing) entries in the column.
# * Helps you spot missing values
#
# **mean:** The average value of the column: sum of values ÷ number of values.
# * helps describe the center or typical behavior of the data
#
# **std:** Standard deviation, which measures the spread or variability in the data.
# * A high std means values are widely spread out; a low std means clustered near the mean.
#
# **min:** The lowest value in the column.
# * Quickly reveals extreme lows or possible errors.
#
# **25%:** First quartile: 25% of the data lies below this value.
# * Useful in understanding the distribution and detecting skewness.
#
# **50%:** Median: 50% of the values are below this (the middle value).
# * More robust than the mean in the presence of outliers.
#
# **75%:** Third quartile: 75% of the data lies below this value.
# * Helps identify the upper end of “normal” values before outliers.
#
# **max:** The maximum value in the column.
# * Shows extreme highs, which could be valid outliers or data entry errors.

# %% [markdown]
#   **6.1 Summary Statistics for Categorical Columns (object type)**
#
#  When you run df.describe(include='object'), Pandas provides summary information for all non-numeric columns, usually containing text values like brand names, locations, colors, etc.
#
# These columns are typically called categorical variables

# %%
df.describe(include='object')
# Out:
#           make   model    trim    body transmission        vin   state  \
# count   548536  548438  548186  545642       493485     558833  558837
# unique      96     973    1963      87            4     550297      64
# top       Ford  Altima    Base   Sedan    automatic  automatic      fl
# freq     93554   19349   55817  199437       475915         22   82945
#
#          color interior              seller  \
# count   558088   558088              558837
# unique      46       17               14263
# top      black    black  nissan-infiniti lt
# freq    110970   244329               19693
#
#                                        saledate
# count                                    558825
# unique                                     3766
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5334

# %% [markdown]
# **count:** The number of non-null (non-missing) entries in the column.
# * Helps you know if there are missing values in a categorical column.
#
# **unique:** Number of distinct categories or different values in that column.
# * Helps you understand how diverse or repetitive the column is.
#
# **top:** The most frequently occurring value (mode) in the column.
# * Helps identify the dominant category in the data.
#
# **freq:** Number of times the top value appears.
# * Shows how much one category dominates the column.

# %% [markdown]
# #**7. Filtering Data in Pandas**
#
# Filtering lets you select only the rows that meet certain conditions.
# This is helpful when you want to work with a specific part of your dataset.
#
# Why Filtering Matters
#
# Imagine you have 558,837 car records, but you only want to analyze:
#
# * Cars made by Toyota
#
# * Cars priced under $15,000
#
# * Cars from the year 2015
#
# Filtering lets you focus only on the rows you need.
#
# **Basic Filtering (Single Condition)**
#
# The most common way to filter data is using boolean indexing.
# You create a True/False condition, and Pandas selects the rows where the condition is True.
#
# Syntax:
#
# df[df['column_name'] condition]

# %% [markdown]
# **7.1 Filtering Numeric Columns**
#
# Greater Than (>)

# %%
# Cars priced above $50,000
expensive_cars = df[df['sellingprice'] > 50000]

# %% [markdown]
# Less Than (<)

# %%
# Cars priced under $5,000
cheap_cars = df[df['sellingprice'] < 5000]

# %% [markdown]
# Equal To (==)

# %%
# Cars from exactly 2015
cars_2015 = df[df['year'] == 2015]

# %% [markdown]
# **7.2 Filtering Text (Categorical) Columns**
#
# Exact Match

# %%
# All Toyota cars

toyotas = df[df['make'] == 'toyota']

# %%
# Cars sold in California

california_cars = df[df['state'] == 'ca']

# %% [markdown]
# **7.3 Multiple Conditions**
#
# Often you need to filter by more than one condition. Use:
#
# * & for AND (both conditions must be true)
#
# * | for OR (at least one condition must be true)
#
# Important: Always wrap each condition in parentheses

# %% [markdown]
# **AND Condition (&)**
#
# Both conditions must be true.

# %%
# Toyota cars priced under $15,000

cheap_toyotas = df[(df['make'] == 'toyota') & (df['sellingprice'] < 15000)]

# %% [markdown]
# OR Condition (|)
#
# At least one condition must be true.

# %%
# Cars that are either Toyota OR Honda

toyota_or_honda = df[(df['make'] == 'toyota') | (df['make'] == 'honda')]

# %% [markdown]
# This selects all rows where the make column is either "toyota" or "honda".

# %% [markdown]
# # **8. Data Cleaning**

# %% [markdown]
# **Cleaning Your Dataset**
#
# Before you can analyze or work with a dataset, you need to find and fix problems in the data.
#
# One of the most common issues in real-world data is missing values — cells that are empty or recorded as NaN (Not a Number).
#
# **Why Cleaning Matters**
#
# * Real-world data is often messy, with problems like:
#
# * Missing values → empty or NaN cells
#
# * Duplicates → repeated rows
#
# * Inconsistencies → typos, wrong formats, or mixed data types
#
# Pandas provides powerful tools to handle these issues so your data is ready for analysis.

# %%
df.isna()
# Out:
#          year   make  model   trim   body  transmission    vin  state  \
# 0       False  False  False  False  False         False  False  False
# 1       False  False  False  False  False         False  False  False
# 2       False  False  False  False  False         False  False  False
# 3       False  False  False  False  False         False  False  False
# 4       False  False  False  False  False         False  False  False
# ...       ...    ...    ...    ...    ...           ...    ...    ...
# 558832  False  False  False  False  False          True  False  False
# 558833  False  False  False  False  False         False  False  False
# 558834  False  False  False  False  False         False  False  False
# 558835  False  False  False  False  False         False  False  False
# 558836  False  False  False  False  False         False  False  False
#
#         condition  odometer  color  interior  seller    mmr  sellingprice  \
# ...

# %% [markdown]
# **This returns a DataFrame of True and False values, where:**
#
# * True means the value is missing
#
# * False means the value is present
#
# To make it more useful, you can check how many missing values exist in each column:

# %%
df.isna().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %% [markdown]
# **.sum():** Adds up the number of True values (the number of missing values) in each column

# %% [markdown]
# **Understanding .isna() vs .isnull()**
#
# Both functions do the same thing — they identify missing values in a DataFrame or Series.
#
# Both return the count of missing values. They are interchangeably used in pandas.

# %%
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %% [markdown]
# #**9. Dropping Null Values in a Dataset (dropna())**
# In real-world datasets, it's common to have missing values, empty cells or entries marked as NaN (Not a Number). These can occur due to:
#
# * Incomplete data collection
# * Data entry errors
# * Data corruption
# * Not applicable fields
#
# Dropping nulls is one way to clean your dataset, especially when:
#
# * The number of missing values is small
# * The missing rows are not critical to your analysis
# * You want to ensure smooth modeling or analysis (most ML algorithms don't handle nulls well)
#
# Caution: Dropping rows with nulls can lead to data loss and potential bias if the missing data follows a pattern. Consider alternatives like imputation (filling missing values) or using algorithms that handle missing data natively.

# %%
# Calculate percentage of missing values
missing_percentage = (df.isnull().sum() / len(df)) * 100  #/len(df)Divides the null count by the total number of rows to get a proportion
print (missing_percentage)
# Out:
# year             0.000000
# make             1.843292
# model            1.860829
# trim             1.905922
# body             2.361154
# transmission    11.694287
# vin              0.000716
# state            0.000000
# condition        2.115107
# odometer         0.016821
# color            0.134028
# interior         0.134028
# seller           0.000000
# mmr              0.006800
# sellingprice     0.002147
# saledate         0.002147
# dtype: float64

# %%
# Drop all rows that have at least one missing value
df_clean = df.dropna()

# %% [markdown]
# * Removes every row that has at least one null value
#
# * The result is stored in a new DataFrame df_clean

# %%
print("Before:", df.shape)
print("After :", df_clean.shape)
# Out:
# Before: (558837, 16)
# After : (472325, 16)

# %% [markdown]
# **9.1 Dropping Columns That Contain Any Missing Values**
#
# Sometimes a column contains missing values in places where they cannot be meaningfully filled. In such cases, you may decide to remove the entire column.

# %%
df_dropped_cols = df.dropna(axis=1)

# %% [markdown]
# **Explanation:**
#
# * axis=1 tells pandas to drop columns instead of rows.
#
# * A column will be removed if at least one missing value is found in it.
#
# * This is a strict approach, so use it only when the column isn’t important or when missing values are too frequent to fix.

# %%
print("before:", df.shape)
print("after :", df_dropped_cols.shape)
# Out:
# before: (558837, 16)
# after : (558837, 3)

# %%
df = df.dropna(subset=['model'])

# %% [markdown]
# ## **10. Selecting Specific Columns**

# %%
# Single Column
df['model']
# Out:
# 0                     Sorento
# 1                     Sorento
# 2                    3 Series
# 3                         S60
# 4         6 Series Gran Coupe
#                  ...
# 558832                   K900
# 558833                   2500
# 558834                     X5
# 558835                 Altima
# 558836                  F-150
# Name: model, Length: 558837, dtype: object

# %%
# Multiple Columns
df[['make', 'model', 'sellingprice']]
# Out:
#           make                model  sellingprice
# 0          Kia              Sorento       21500.0
# 1          Kia              Sorento       21500.0
# 2          BMW             3 Series       30000.0
# 3        Volvo                  S60       27750.0
# 4          BMW  6 Series Gran Coupe       67000.0
# ...        ...                  ...           ...
# 558832     Kia                 K900       33000.0
# 558833     Ram                 2500       30800.0
# 558834     BMW                   X5       34000.0
# 558835  Nissan               Altima       11100.0
# 558836    Ford                F-150       26700.0
#
# [558837 rows x 3 columns]

# %% [markdown]
# # **11. Renaming Columns in Pandas**
#
# Renaming columns is a common task when working with datasets. You might need to rename columns to:
#
# * Make names more readable or descriptive
# * Clean up messy or inconsistent names
# * Standardize naming conventions (lowercase, no spaces)
# * Match column names with another dataset for merging
# * Make names Python-friendly (no spaces or special characters)

# %% [markdown]
# **11.1 Renaming Specific Columns**
#
# **Using rename() Method**
#
# The most flexible way to rename columns. Pass a dictionary mapping old names to new names.
#
# **Syntax:**
#
# df.rename(columns={'old_name': 'new_name'}, inplace=True)
# # OR
# df = df.rename(columns={'old_name': 'new_name'})

# %% [markdown]
# **11.2 Single Column:**

# %%
# Rename 'sellingprice' to 'selling_price'
df = df.rename(columns={'sellingprice': 'selling_price'})

print(df.columns.tolist())
# Out:
# ['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state', 'condition', 'odometer', 'color', 'interior', 'seller', 'mmr', 'selling_price', 'saledate']

# %% [markdown]
# **11.3 Multiple Columns:**

# %%
# Rename multiple columns at once

df = df.rename(columns={
    'sellingprice': 'selling_price',
    'mmr': 'market_value',
    'vin': 'vehicle_id',
    'saledate': 'sale_date'
})

print(df.columns.tolist())
# Out:
# ['year', 'make', 'model', 'trim', 'body', 'transmission', 'vehicle_id', 'state', 'condition', 'odometer', 'color', 'interior', 'seller', 'market_value', 'selling_price', 'sale_date']

# %% [markdown]
# **11.4 Using inplace=True:**
#
# Note: **inplace=True** modifies the original DataFrame. Without it, you must assign the result back to df.

# %%
# Modify the original DataFrame directly

df.rename(columns={'odometer': 'mileage'}, inplace=True)

# %% [markdown]
# It tells pandas:
#
#     Change the column name from 'odometer' to 'mileage'.
#
# inplace=True
#
# This means:
#
#     Apply the change directly to df instead of returning a new DataFrame.

# %% [markdown]
# # **12. GroupBy and Aggregations in Pandas**
#
# The GroupBy operation in Pandas is used to analyze data by categories and compute summary statistics for each group. This is essential when you want to understand patterns or compare groups within your dataset.
#
# **With groupby(), you can answer practical questions such as:**
#
# * Which car brand has the highest average selling price?
#
# * How many cars were sold in each state?
#
# * What is the average condition rating for each seller?
#
#
# **12.1 How GroupBy Works**
#
# You split your DataFrame into groups based on the values in one or more columns, and then apply an aggregation function.
#
# Common aggregation functions include:
#
# * .mean() — average
#
# * .sum() — total
#
# * .count() — number of rows
#
# * .min() — smallest value
#
# * .max() — largest value
#
# * .median() — middle value
#
# You can group by one column or multiple columns, and then chain the result with sorting, filtering, or plotting.

# %% [markdown]
# 1. Average selling price per car brand

# %%
df.groupby('make')['selling_price'].mean()
# Out:
# make
# Acura           14017.268260
# Aston Martin    54812.000000
# Audi            19915.432782
# BMW             21441.895748
# Bentley         74367.672414
#                     ...
# subaru           3710.416667
# suzuki           4810.000000
# toyota           7339.105263
# volkswagen       6145.833333
# vw              13672.916667
# Name: selling_price, Length: 96, dtype: float64

# %% [markdown]
# gives a simple, clean summary of average price per brand — way easier to interpret than scanning all 500,000+ rows.

# %% [markdown]
# 2. Number of cars sold in each state

# %%
df.groupby('state')['selling_price'].count().sort_values(ascending=False).head(10)
# Out:
# state
# fl    82945
# ca    73148
# pa    53907
# tx    45913
# ga    34750
# nj    27784
# il    23478
# nc    21845
# oh    21575
# tn    20895
# Name: selling_price, dtype: int64

# %% [markdown]
# Shows the top-selling states by average price

# %% [markdown]
# **12.2 Grouping by Multiple Columns**

# %%
df.groupby(['make', 'state'])['selling_price'].mean()
# Out:
# make   state
# Acura  ab        2300.000000
#        az       11437.790698
#        ca       14106.790865
#        co       15024.137931
#        fl       11680.376344
#                     ...
# vw     mn        1500.000000
#        oh       21850.000000
#        on        7606.250000
#        va         500.000000
#        wa        2500.000000
# Name: selling_price, Length: 2061, dtype: float64

# %% [markdown]
# # **13. Data Visualization with Matplotlib**
#
# Data Visualization is the process of turning raw data into visual formats like charts, graphs, plots, and maps.
#
# * It helps you see patterns, trends, and insights quickly.
#
# * Our brains understand pictures faster than tables.
#
# * A well-designed chart can tell a story at a glance that might take pages of numbers to explain.
#
#  **13.1 Common Visualization Types:**
#
# | Chart Type         | When to Use                      | Code Example                    |
# | ------------------ | -------------------------------- | ------------------------------- |
# | **Line**           | Trends over time                 | `plt.plot(x, y)`                |
# | **Bar**            | Compare categories               | `plt.bar(x, y)`                 |
# | **Horizontal Bar** | Long category names              | `plt.barh(x, y)`                |
# | **Histogram**      | Data distribution                | `plt.hist(data)`                |
# | **Pie**            | Parts of a whole                 | `plt.pie(values, labels=names)` |
# | **Scatter**        | Relationship between 2 variables | `plt.scatter(x, y)`             |
# | **Box Plot**       | Distribution & outliers          | `plt.boxplot(data)`             |

# %% [markdown]
# **13.2 Basic Structure of a Matplotlib Chart**
#
# Every Matplotlib chart follows 4 simple steps:

# %%
import matplotlib.pyplot as plt

# %%
# 1. Create the plot (figure size)
plt.figure(figsize=(10, 6))  # Width x Height in inches

# 2. Add your data
plt.plot(x_data, y_data)      # Or use plt.bar(), plt.scatter(), etc.

# 3. Customize the chart
plt.title("My Chart Title")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")

# 4. Display the chart
plt.show()

# %% [markdown]
# 1. Create the plot → Decide the figure size using plt.figure(figsize=(width, height)).
#
# 2. Add your data → Use the appropriate plot type (plot, bar, scatter, hist, etc.).
#
# 3. Customize it → Add title, axis labels, and other formatting.
#
# 3. Display it → plt.show() renders the chart on screen.

# %% [markdown]
# 1. **Line Plot – Best for Showing how values change over time**
#
# Year vs average selling price.

# %%
yearly = df.groupby('year')['selling_price'].mean()

plt.plot(yearly.index, yearly.values)
plt.xlabel('Year')
plt.ylabel('Average Selling Price')
plt.title('Average Car Price Over the Years')
plt.show()

# %% [markdown]
# 2. **Bar Chart – Best for Comparing values across different categories**
#
# top 5 car brands by count.

# %%
top_makes = df['make'].value_counts().head()

plt.bar(top_makes.index, top_makes.values)
plt.xticks(rotation=45)
plt.xlabel('Make')
plt.ylabel('Count')
plt.title('Top 5 Car Brands')
plt.show()

# %% [markdown]
# 3. **Horizontal Bar Chart – For Long Category Names**
#
# top 10 models by count.

# %%
top_models = df['model'].value_counts().head(10)

plt.barh(top_models.index, top_models.values)
plt.xlabel('Count')
plt.ylabel('Model')
plt.title('Top 10 Car Models')
plt.show()

# %% [markdown]
# 4. **Histograms - Distribution of Values**
#
# Best for: Understanding how values are distributed

# %%
plt.hist(df['selling_price'], bins=30)
plt.xlabel('selling_price')
plt.ylabel('Frequency')
plt.title('selling_price Distribution')
plt.show()

# %% [markdown]
# 5. **Pie Charts - Parts of a Whole**
#
# Best for: Showing proportions

# %%
colors = df['color'].value_counts().head(5)

plt.pie(colors.values, labels=colors.index, autopct='%1.1f%%')
plt.title('Top 5 Car Colors')
plt.show()

# %% [markdown]
# 6. **Scatter Plots - Relationships Between Variables**
#
# Best for: Showing correlation between two variables

# %%
plt.scatter(df['market_value'], df['selling_price'], alpha=0.3)
plt.xlabel('market_value')
plt.ylabel('Selling Price')
plt.title('market_value vs Selling Price')
plt.show()

# %% [markdown]
# 7. **Box Plots - Statistical Distribution**
#
# Best for: Comparing distributions and identifying outliers

# %%
plt.boxplot(df['selling_price'].dropna())
plt.ylabel('Selling Price')
plt.title('Selling Price Distribution')
plt.show()

# %% [markdown]
# # **Vehicle Sales Dataset**
#
# | DATA  | MEANING |
# |-------|---------|
# |Year: |The manufacturing year of the vehicle.
# |make: |The brand or manufacturer of the vehicle.
# |model |The specific model of the car (e.g., Corolla, F-150, Civic).
# |trim |The trim level or variant of the model, indicating specific features or equipment (e.g., LE, SE, Limited)
# |Body |The type of car body (e.g., sedan, SUV, coupe, hatchback, convertible)
# |transmission |The type of transmission (e.g., automatic, manual, CVT).
# |Vin |Vehicle Identification Number – a unique code used to identify individual motor vehicles.
# |state |The U.S. state where the car was sold or registered.
# |condition | A numeric representation of the car’s condition, typically on a scale (e.g., 1–5 or 1–10). Higher values usually mean better condition.
# |odometer| A numeric representation of the car’s condition, typically on a scale (e.g., 1–5 or 1–10). Higher values usually mean better condition.
# |color | The exterior color of the vehicle.
# |interior |The color or material of the interior (e.g., black leather, gray cloth).
# |seller | The name or ID of the seller or dealership selling the car.
# |mmr | Manheim Market Report value — an estimated market price for the vehicle based on auction data, condition, and other factors
# |sellingprice | The actual price at which the car was sold.
# |saledate |The date the vehicle was sold

# %% [markdown]
# # **Additional Material**

# %% [markdown]
# * [Learn Pandas in 1 hour!](https://www.youtube.com/watch?v=VXtjG_GzO7Q)
# * [Alex The Analyst- Learn Pandas in Under 3 Hours | Filtering, Joins, Indexing, Data Cleaning, Visualizations](https://www.youtube.com/watch?v=Mdq1WWSdUtw)
#
# * [Data Science with Onur - Data Cleaning in Pandas](https://www.youtube.com/watch?v=I7DZP4rVQOU)
#
# * [Khan Academy - Python tutorials](https://www.khanacademy.org/computing/computer-programming)
#
# *Note: Suggested resources are not affiliated or sponsoring this project.*
